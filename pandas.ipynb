# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(df.head()) # top 5 rows
print(df.tail()) # last 5 rows
print(df.shape) # number of rows and columns
print(df.columns) # columns names
print(df.info()) # summary of dataframe
print(df.describe()) # summary statistics for numerical columns
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# ...

# %% [markdown]
# Accessing data

# %%
print(df['pclass'])
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
# multiple column selection
print(df[['pclass','age']])
# Out:
#      pclass   age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# iloc - index based selection
# loc - label based selection

# %%
df.iloc[78] #index based selection
# Out:
# survived                 1
# pclass                   2
# sex                   male
# age                   0.83
# sibsp                    0
# parch                    2
# fare                  29.0
# embarked                 S
# class               Second
# who                  child
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 78, dtype: object

# %%
df.iloc[[0,2,4,9]]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df.iloc[5:10] # slicing rows
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male   NaN      0      0   8.4583        Q   Third    man
# 1              0    male  54.0      0      0  51.8625        S   First    man
# 3              0    male   2.0      3      1  21.0750        S   Third  child
# 3              1  female  27.0      0      2  11.1333        S   Third  woman
# 2              1  female  14.0      1      0  30.0708        C  Second  child
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN   Queenstown    no   True
# 1             True    E  Southampton    no   True
# 3            False  NaN  Southampton    no  False
# 3            False  NaN  Southampton   yes  False
# 2            False  NaN    Cherbourg   yes  False

# %%
df= df.set_index('pclass')  # vaise to id ko index bnate h but isme h nii.. unique values ko hi index banate h kchouse.csv vala dataset use kro 
df.head()
# Out:
#         survived     sex   age  sibsp  parch     fare embarked  class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
# 3              1  female  26.0      0      0   7.9250        S  Third  woman
# 1              1  female  35.0      1      0  53.1000        S  First  woman
# 3              0    male  35.0      0      0   8.0500        S  Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True

# %% [markdown]
# DATA CLEANING

# %%
print(df.isnull().sum())
# Out:
# survived         0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# - data handling and data deletion two ways to handle the null values in a dataset
# - data handling agr column important h to
# - data deletion agar column imp nii h

# %% [markdown]
# - handling : fillna
# - deletion: dropna for deletion of rows of null values
# - deletion: drop for deleting the whole colulmn

# %%
df['age'].fillna(df['age'].mean(),inplace=True) # fill null values in 'age' with mean
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21452\1706205798.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(),inplace=True) # fill null values in 'age' with mean

# %% [markdown]
# Filtering Data

# %%
adults = df[df['age']>=18]
females = df[df['sex']=='female']
survivors = df[df['survivor']==1]
print(adults)
print(females)
print(survivors)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'survivor'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 adults = df[df['age']>=18]
# ...
